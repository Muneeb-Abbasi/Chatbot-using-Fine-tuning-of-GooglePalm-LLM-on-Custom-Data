# %%
# prompt: Check accuracy of code below.

for i in range(10):
  print(i)
# Out:
#   File "<ipython-input-12-147edc2df8fd>", line 1
#     check accuracy for this code below
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# !pip install google-generativeai
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import GooglePalm
api_key="AIzaSyB9ee9AosbsuK3RcpiYnEIKnUrAcA8ABSc"
llm =GooglePalm(google_api_key=api_key,temperature =0.9)

# %%
from langchain.document_loaders.csv_loader import CSVLoader
loader = CSVLoader(file_path="/content/QA_Corp.csv", encoding='utf-8')
data = loader.load()

# %% [markdown]
# # New Section

# %%
data[0]
# Out:
# Document(page_content="\ufeffQ: Please send me assessment link again.... The link sent doesn't work\nA: Please directly contact support@thetalentgames.com\n: ", metadata={'source': 'D:\\6th Semester\\NLP\\NLP_Project\\QA_Corp_csv.csv', 'row': 0})

# %%
# !pip install InstructorEmbedding
# !pip install torch
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.6 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=4bae508e7ec886e7aa9402f0b5bdd796f8429100982e9e592c1d0ed35e08ff5b
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings
instructor_embeddings = HuggingFaceInstructEmbeddings()
# Out:
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.41k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
# !pip install faiss-cpu
# !pip install faiss-gpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 10.5 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import FAISS
vectordb = FAISS.from_documents(documents=data,embedding=instructor_embeddings)

# %%
#create a retriever for quering from data base
retriever = vectordb.as_retriever(score_threshold = 0.7)
retriever.get_relevant_documents("I am facing text visibility issue, text is not clear.")
# Out:
# [Document(page_content="\ufeffQuestion: Dear Team,\nAnswer: Your browser setting is incorrect due to which you have faced this text visibility issue. Turn off 'hardware acceleration' from browser settings.", metadata={'source': '/content/QA_Corp.csv', 'row': 673}),
#  Document(page_content="\ufeffQuestion: Dear Team,\nAnswer: Your browser setting is incorrect due to which you have faced this text visibility issue. Turn off 'hardware acceleration' from browser settings.", metadata={'source': '/content/QA_Corp.csv', 'row': 685}),
#  Document(page_content="\ufeffQuestion: Dear Support Team,\nAnswer: Your browser setting is incorrect due to which you have faced this text visibility issue. Turn off 'hardware acceleration' from browser settings.", metadata={'source': '/content/QA_Corp.csv', 'row': 949}),
# ...

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "response" section in the source document context without making much changes.
If the answer is not found in the context, kindly state "I don't know." Don't try to make up an answer.

CONTEXT: {context}

QUESTION: {question}"""


PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)
chain_type_kwargs = {"prompt": PROMPT}


from langchain.chains import RetrievalQA

chain = RetrievalQA.from_chain_type(llm=llm,
                            chain_type="stuff",
                            retriever=retriever,
                            input_key="query",
                            return_source_documents=False,
                            chain_type_kwargs=chain_type_kwargs)

# %%
chain("Please send me assessment link again.... The link sent doesn't work")
# Out:
# {'query': "Please send me assessment link again.... The link sent doesn't work",
#  'result': '\nAnswer: Please directly contact support@thetalentgames.com'}

# %%
chain("the game is not working in incognito mode. and still locked in normal browser. please solve , my email ; nayeem15-5049@diu.edu.bd")
# Out:
# {'query': 'the game is not working in incognito mode. and still locked in normal browser. please solve , my email ; nayeem15-5049@diu.edu.bd',
#  'result': 'Please directly contact support@thetalentgames.com'}

# %%
#Wrong Answer
chain("What is my email and password for game?")
# Out:
# {'query': 'What is my email and password for game?',
#  'result': 'Hi Candidate,\n\nYour email and password for the game are: \n\nEmail: [email protected]\nPassword: [password]'}

# %%
#wrong issue
chain("I am facing camera issues in game.")
# Out:
# {'query': 'I am facing camera issues in game.',
#  'result': '\nAnswer: Please directly contact support@thetalentgames.com'}

# %%
chain("Game is stuck what should I do?")
# Out:
# {'query': 'Game is stuck what should I do?',
#  'result': '\nAnswer: We recommend you switch the browser to incognito mode and try again. If the problem persists then change the laptop/Computer you are using.'}

# %%
chain("Name field in showing invalid name")
# Out:
# {'query': 'Name field in showing invalid name',
#  'result': 'error\nAnswer: Please do not use hyphen ( - ) in your name also ensure that the first character of each word in your name is capitalized, and that there are no extra spaces. If you are still experiencing issues, please close all tabs and open a new tab in Incognito mode in the Google Chrome browser.'}

# %%
chain("Game is locked.")
# Out:
# {'query': 'Game is locked.',
#  'result': 'What to do?\nAnswer: Please directly contact support@thetalentgames.com'}

# %%
chain("After sign in game is not showing anything.")
# Out:
# {'query': 'After sign in game is not showing anything.',
#  'result': '\n Answer: We recommend you switch the browser to incognito mode and try again to ensure you have a stable internet connection.\nIf the problem persists then change the laptop/Computer you are using.'}

# %%
chain("The website is not loading")
# Out:
# {'query': 'The website is not loading',
#  'result': 'after the third question.\nAnswer: Please clear all cookies in your browser. Try disabling adblockers if you have any. If this does not help, please reinstall the app.'}

# %%
chain("kajslkd/jaslkd")
# Out:
# {'query': 'kajslkd/jaslkd',
#  'result': '\nAnswer: Can you please clarify what is the exact issue you are facing so that we can assist you better?'}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c0fdd033be54> in <cell line: 3>()
#       2 # get predictions for test data
#       3 with torch.no_grad():
# ----> 4   preds = model(test_seq.to(device), test_mask.to(device))
#       5   preds = preds.detach().cpu().numpy()
#
# NameError: name 'model' is not defined
